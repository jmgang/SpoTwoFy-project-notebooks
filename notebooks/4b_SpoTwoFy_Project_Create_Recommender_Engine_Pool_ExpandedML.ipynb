# %% [markdown]
# <a href="https://colab.research.google.com/github/jmgang/SpoTwoFy-project-notebooks/blob/main/notebooks/4b_SpoTwoFy_Project_Create_Recommender_Engine_Pool_ExpandedML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creating a Recommender Engine Pool

# %% [markdown]
# *What is a recommender engine?*
#
# A recommender engine is an information filtering system that predicts a user's preferences for a set of items (such as products, movies, or music) based on their previous interactions with those items or similar items, and provides personalized recommendations for new items.
#
# *What is a recommender engine pool?*
#
# The recommender engine pool is the data source from which the recommender engine gets its recommendations. It is made up of the (1) items considered for the recommendation and (2) measure/s that determines its fitness to be recommended.
#
# | item | measure1 | measure2 |
# |------|----------|----------|
# | 1    | 0.1      | 0.5      |
# | 2    | 0.2      | 0.6      |
# | 3    | 0.3      | 0.7      |
#
#
# In this notebook, we will create a track recommendation pool from the daily top 200 tracks data and generate track recommendations for a sample track.

# %%
# !pip install scikit-learn==1.3.2 -q
# !pip install scikit-learn --upgrade
# !pip install imbalanced-learn --upgrade
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 74.0 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.11.0-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.6/235.6 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.11.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.2.0)
# Installing collected packages: imbalanced-learn
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.10.1
#     Uninstalling imbalanced-learn-0.10.1:
#       Successfully uninstalled imbalanced-learn-0.10.1
# Successfully installed imbalanced-learn-0.11.0

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import joblib # joblib==1.2.0, install if needed
import requests
from io import BytesIO
pd.options.mode.chained_assignment = None

# %%
# Mount GDrive folders
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Set home directory
import os
home_dir = "/content/drive/MyDrive/Colab Notebooks/Sprint 3/"
os.chdir(home_dir)

# %%
DATA_DIRECTORY = 'https://raw.githubusercontent.com/jmgang/SpoTwoFy-project-notebooks/main/data/'
MODEL_DIRECTORY = 'https://raw.githubusercontent.com/jmgang/SpoTwoFy-project-notebooks/main/model_data/'

# %%
def load_playlist_data(genre_names):
    playlist_df_list = []
    for genre in tqdm(genre_names):
        filename = DATA_DIRECTORY + 'playlists/' + genre.lower() + '_playlist_data.csv'
        print(filename)
        pdf = pd.read_csv(filename)
        pdf['genre'] = genre.lower()
        playlist_df_list.append(pdf)
    return pd.concat(playlist_df_list)

# %%
def load_track_data(genre_names):
    track_df_list = []
    for genre in tqdm(genre_names):
        filename = DATA_DIRECTORY + 'playlists/' + genre.lower() + '_playlist_tracks_data.csv'
        tdf = pd.read_csv(filename)
        tdf = tdf[~tdf.duplicated(subset=['track_id'])]  # Remove duplicates based on 'track_id'
        tdf['genre'] = genre.lower()
        track_df_list.append(tdf)
    return pd.concat(track_df_list)

# %% [markdown]
# ## 1. Read data

# %% [markdown]
# Read playlist data

# %%
# chart_tracks_df = pd.read_csv('data/ph_spotify_daily_charts_tracks.csv')
# chart_tracks_df.head()

genre_names = ['opm', 'pinoy', 'alternative_rock', 'pop', 'sad_opm']
playlist_df = load_playlist_data(genre_names)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# https://raw.githubusercontent.com/jmgang/SpoTwoFy-project-notebooks/main/data/playlists/opm_playlist_data.csv
#  40%|████      | 2/5 [00:00<00:00,  3.86it/s]
# https://raw.githubusercontent.com/jmgang/SpoTwoFy-project-notebooks/main/data/playlists/pinoy_playlist_data.csv
# https://raw.githubusercontent.com/jmgang/SpoTwoFy-project-notebooks/main/data/playlists/alternative_rock_playlist_data.csv
#  80%|████████  | 4/5 [00:00<00:00,  6.06it/s]
# https://raw.githubusercontent.com/jmgang/SpoTwoFy-project-notebooks/main/data/playlists/pop_playlist_data.csv
# https://raw.githubusercontent.com/jmgang/SpoTwoFy-project-notebooks/main/data/playlists/sad_opm_playlist_data.csv
# 100%|██████████| 5/5 [00:00<00:00,  5.54it/s]

# %% [markdown]
# Read charts tracks data

# %%
filename = DATA_DIRECTORY + 'charts/ph_spotify_daily_charts_tracks.csv'
charts_df = pd.read_csv(filename)
charts_df.head()
# Out:
#                  track_id            track_name               artist_id  \
# 0  0kN8xEmgMW9mh7UmDYHlJP  Versace on the Floor  0du5cEVh5yTK9QJze8zA0C
# 1  5uCax9HTNlzGybIStD3vDh  Say You Won't Let Go  4IWBUUAFIplrNtaOHcJPRM
# 2  7BKLCZ1jbUBVqRi2FVlTVw                Closer  69GGBxA162lTqCwzJG5jLp
# 3  2rizacJSyD9S1IQUxUxnsK           All We Know  69GGBxA162lTqCwzJG5jLp
# 4  5MFzQMkrl1FOOng9tq6R9r      Don't Wanna Know  04gDigrS5kc9YWfZHwBETP
#
#         artist_name                album_id  duration release_date  \
# 0        Bruno Mars  4PgleR09JVnm3zY1fW3XBA    261240   2016-11-17
# 1      James Arthur  7oiJYvEJHsmYtrgviAVIBD    211466   2016-10-28
# 2  The Chainsmokers  0rSLgV8p5FzfnqlEk4GzxE    244960   2016-07-29
# 3  The Chainsmokers  0xmaV6EtJ4M3ebZUPRnhyb    194080   2016-09-29
# 4          Maroon 5  0fvTn3WXF39kQs9i3bnNpP    214480   2016-10-11
#
#    popularity  danceability  energy   key  loudness  mode  speechiness  \
# 0          75         0.578   0.574   2.0    -6.209   1.0       0.0454
# 1          87         0.358   0.557  10.0    -7.398   1.0       0.0590
# 2          85         0.748   0.524   8.0    -5.599   1.0       0.0338
# 3          71         0.662   0.586   0.0    -8.821   1.0       0.0307
# 4           0         0.783   0.623   7.0    -6.126   1.0       0.0800
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0         0.196           0.00000    0.0830    0.301  174.152
# 1         0.695           0.00000    0.0902    0.494   85.043
# 2         0.414           0.00000    0.1110    0.661   95.010
# 3         0.097           0.00272    0.1150    0.296   90.000
# 4         0.338           0.00000    0.0975    0.447  100.048

# %% [markdown]
# Read tracks data

# %%
feature_cols = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness',\
                'liveness', 'valence', 'tempo']

# %%
tracks_df = load_track_data(genre_names)
# Out:
# 100%|██████████| 5/5 [00:01<00:00,  4.15it/s]

# %%
tracks_df['genre'].value_counts()
# Out:
# pop                 7594
# pinoy               5027
# alternative_rock    3866
# opm                 1283
# sad_opm              517
# Name: genre, dtype: int64

# %%
tracks_df = pd.concat([tracks_df, charts_df], axis=0, ignore_index=True)

# %% [markdown]
# Remove tracks with no available/incomplete audio features

# %%
print(len(tracks_df))
tracks_df = tracks_df.dropna(subset=feature_cols)
print(len(tracks_df))
# Out:
# 23055
# 23054

# %%
tracks_df
# Out:
#                      track_id                            track_name  \
# 0      3OpGUlDmRUXh0NkIYWoIlD                             Your Song
# 1      761frfZtZ8I2g70UsjFfBK                 I Need You More Today
# 2      4r3wYgrJ3Q30ldSk05e6KP                Kiss (Never Let Me Go)
# 3      3VcVQmMivq2ISfKUmIuvMK                               Rainbow
# 4      1FHCU1rDAeaPsBW9byjJ0Q                                 12:51
# ...                       ...                                   ...
# 23050  4hbU7BVioG3WnoRNEy5YUf                                Kitsch
# 23051  6TKDFOO6Rv6VuB9PxcXQO3                                G Wolf
# 23052  69CrOS7vEHIrhC2ILyEi0s                                FLOWER
# 23053  2YXswOX5aKv6OHRKUcAMLQ                        All Eyes On Me
# 23054  5qxH7LdIp4QAf1HmSX2Kfu  Cupid Twin Version (Sped Up) - Remix
#
#                     artist_id       artist_name                album_id  \
# 0      2XHTklRsNMOOQT56Zm3WS4  Parokya Ni Edgar  0kV35wyXIJKk04VRG0DdF4
# 1      3XEHRbR9NMWfNzQ6TQMS9M      Caleb Santos  4TyVEjoScAou6qVjhXyYfp
# 2      0001ZVMPt41Vwzt1zsmuzp      Thyro & Yumi  0tSrGWDVpvBzlD8OWSRmg6
# 3      6ZgBJRjJsK1iOJGKGZxEUv      South Border  6bMej3xtNOTiiHLdhR4wzX
# 4      09DdQEMQaaq0f99vqqub3V   krissy & ericka  5M4GVkxOl3joHIkvNrAlbJ
# ...                       ...               ...                     ...
# 23050  6RHTUrRF63xao58xh9FXYJ               IVE  7KgFOJg5QAU9Ex9L2oTy67
# 23051  3PDFGpPl4ienSn5Vwisfrh            Flow G  5NyBYQ3AAjobmwtKXicPzR
# 23052  6UZ0ba50XreR4TM8u322gs             JISOO  4QuczuzDZNzCDli5Gz6DQ0
# 23053  6UZ0ba50XreR4TM8u322gs             JISOO  4QuczuzDZNzCDli5Gz6DQ0
# 23054  7xj1YIDzHU6vkUwP76NEyx     Music Factory  4ahvSRXxDEZBO81X2Lq1Ie
#
#        duration release_date  popularity  danceability  energy  ...  \
# 0      168493.0         2003          70         0.636   0.159  ...
# 1      233728.0   2016-12-02          63         0.474   0.522  ...
# 2      259714.0   2020-04-17          11         0.571   0.534  ...
# 3      347120.0   2005-01-01          63         0.660   0.224  ...
# 4      246280.0   2011-01-01          61         0.503   0.357  ...
# ...         ...          ...         ...           ...     ...  ...
# 23050  195440.0   2023-03-27          80         0.800   0.792  ...
# 23051  197328.0   2021-08-15          66         0.744   0.572  ...
# 23052  173134.0   2023-03-31          82         0.841   0.384  ...
# 23053  163522.0   2023-03-31          78         0.779   0.646  ...
# 23054  146236.0   2023-03-16          74         0.609   0.752  ...
#
#        instrumentalness  liveness  valence    tempo             playlist_id  \
# 0              0.000000    0.1120    0.658  119.766  37i9dQZF1DX4olOMiqFeqU
# 1              0.000000    0.1230    0.448  157.225  37i9dQZF1DX4olOMiqFeqU
# 2              0.000000    0.3000    0.544  139.972  37i9dQZF1DX4olOMiqFeqU
# 3              0.000002    0.1010    0.382   88.011  37i9dQZF1DX4olOMiqFeqU
# 4              0.000000    0.1280    0.438  136.135  37i9dQZF1DX4olOMiqFeqU
# ...                 ...       ...      ...      ...                     ...
# 23050          0.000001    0.0495    0.455  102.000                     NaN
# 23051          0.000000    0.0949    0.535  156.071                     NaN
# 23052          0.000002    0.0735    0.597  123.961                     NaN
# 23053          0.000027    0.0943    0.628  110.048                     NaN
# 23054          0.000007    0.1720    0.903  144.143                     NaN
#
#        playlist_name  genre  duration_ms  num_artists duration_mins
# 0      OPM Favorites    opm          NaN          NaN           NaN
# 1      OPM Favorites    opm          NaN          NaN           NaN
# 2      OPM Favorites    opm          NaN          NaN           NaN
# 3      OPM Favorites    opm          NaN          NaN           NaN
# 4      OPM Favorites    opm          NaN          NaN           NaN
# ...              ...    ...          ...          ...           ...
# 23050            NaN    NaN          NaN          NaN           NaN
# 23051            NaN    NaN          NaN          NaN           NaN
# 23052            NaN    NaN          NaN          NaN           NaN
# 23053            NaN    NaN          NaN          NaN           NaN
# 23054            NaN    NaN          NaN          NaN           NaN
#
# [23054 rows x 25 columns]

# %% [markdown]
# Remove duplicate tracks

# %%
print(len(tracks_df))
tracks_df = tracks_df.drop_duplicates(subset=['artist_id','track_name'])
print(len(tracks_df))
# Out:
# 23054
# 17029

# %%
tracks_df['genre'].fillna('unknown', inplace=True)

# %%
tracks_df['genre'].value_counts()
# Out:
# pop                 6272
# pinoy               3842
# alternative_rock    2926
# unknown             2626
# opm                 1178
# sad_opm              185
# Name: genre, dtype: int64

# %% [markdown]
# ## 2. Load model pipeline

# %%
response = requests.get(MODEL_DIRECTORY + 'genre_classifier_hale_smote_xgboost.pkl')
pipeline = joblib.load(BytesIO(response.content))
pipeline
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()), ('sampler', SMOTE(random_state=42)),
#                 ('model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=1.0, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.01,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=9, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=150, n_jobs=None,
#                                num_parallel_tree=None,
#                                objective='multi:softprob', ...))])

# %%
pipeline.named_steps['model']
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=150, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %% [markdown]
# ## 3. Predict Track Genres

# %% [markdown]
# Define features and genre id lookup dict

# %%
genre_lookup = {0: 'alternative_rock', 1: 'pop', 2: 'sad_opm'}

# %% [markdown]
# Predict genre of each charting track using loaded pipeline

# %%
tracks_df['predicted_genre_id'] = pipeline.predict(tracks_df[feature_cols])
tracks_df['predicted_genre'] = tracks_df['predicted_genre_id'].map(genre_lookup)
tracks_df.head()
# Out:
#                  track_id              track_name               artist_id  \
# 0  3OpGUlDmRUXh0NkIYWoIlD               Your Song  2XHTklRsNMOOQT56Zm3WS4
# 1  761frfZtZ8I2g70UsjFfBK   I Need You More Today  3XEHRbR9NMWfNzQ6TQMS9M
# 2  4r3wYgrJ3Q30ldSk05e6KP  Kiss (Never Let Me Go)  0001ZVMPt41Vwzt1zsmuzp
# 3  3VcVQmMivq2ISfKUmIuvMK                 Rainbow  6ZgBJRjJsK1iOJGKGZxEUv
# 4  1FHCU1rDAeaPsBW9byjJ0Q                   12:51  09DdQEMQaaq0f99vqqub3V
#
#         artist_name                album_id  duration release_date  \
# 0  Parokya Ni Edgar  0kV35wyXIJKk04VRG0DdF4  168493.0         2003
# 1      Caleb Santos  4TyVEjoScAou6qVjhXyYfp  233728.0   2016-12-02
# 2      Thyro & Yumi  0tSrGWDVpvBzlD8OWSRmg6  259714.0   2020-04-17
# 3      South Border  6bMej3xtNOTiiHLdhR4wzX  347120.0   2005-01-01
# 4   krissy & ericka  5M4GVkxOl3joHIkvNrAlbJ  246280.0   2011-01-01
#
#    popularity  danceability  energy  ...  valence    tempo  \
# 0          70         0.636   0.159  ...    0.658  119.766
# 1          63         0.474   0.522  ...    0.448  157.225
# 2          11         0.571   0.534  ...    0.544  139.972
# 3          63         0.660   0.224  ...    0.382   88.011
# 4          61         0.503   0.357  ...    0.438  136.135
#
#               playlist_id  playlist_name  genre  duration_ms  num_artists  \
# 0  37i9dQZF1DX4olOMiqFeqU  OPM Favorites    opm          NaN          NaN
# 1  37i9dQZF1DX4olOMiqFeqU  OPM Favorites    opm          NaN          NaN
# 2  37i9dQZF1DX4olOMiqFeqU  OPM Favorites    opm          NaN          NaN
# 3  37i9dQZF1DX4olOMiqFeqU  OPM Favorites    opm          NaN          NaN
# 4  37i9dQZF1DX4olOMiqFeqU  OPM Favorites    opm          NaN          NaN
#
#    duration_mins  predicted_genre_id predicted_genre
# 0            NaN                   2         sad_opm
# 1            NaN                   2         sad_opm
# 2            NaN                   1             pop
# 3            NaN                   2         sad_opm
# 4            NaN                   2         sad_opm
#
# [5 rows x 27 columns]

# %%
tracks_df['predicted_genre'].value_counts()
# Out:
# pop                 8061
# alternative_rock    4803
# sad_opm             4165
# Name: predicted_genre, dtype: int64

# %% [markdown]
# ## 4. Create recommender engine pool with predicted genres and probabilities

# %% [markdown]
# For a multiclass classification problem, `predict_proba()` returns the probability estimates for each class. For example, if you are building a model to predict the type of flower, predict_proba will output the probabilities of each flower type.
#
# These probabilities are computed based on the input features and the model parameters learned during the training process. They are useful in making decisions based on the predicted class labels, especially when the model is uncertain about the correct class label.
#
# We will use the probabilities from `predict_proba()` as metrics for the recommender engine pool

# %% [markdown]
# Show probabilities for all genres and for the predicted genre

# %%
tracks_df['genre_probabilities']= pipeline.predict_proba(tracks_df[feature_cols]).tolist()
tracks_df['predicted_genre_proba'] = tracks_df['genre_probabilities'].apply(lambda x: max(x))
tracks_df.head()
# Out:
#                  track_id              track_name               artist_id  \
# 0  3OpGUlDmRUXh0NkIYWoIlD               Your Song  2XHTklRsNMOOQT56Zm3WS4
# 1  761frfZtZ8I2g70UsjFfBK   I Need You More Today  3XEHRbR9NMWfNzQ6TQMS9M
# 2  4r3wYgrJ3Q30ldSk05e6KP  Kiss (Never Let Me Go)  0001ZVMPt41Vwzt1zsmuzp
# 3  3VcVQmMivq2ISfKUmIuvMK                 Rainbow  6ZgBJRjJsK1iOJGKGZxEUv
# 4  1FHCU1rDAeaPsBW9byjJ0Q                   12:51  09DdQEMQaaq0f99vqqub3V
#
#         artist_name                album_id  duration release_date  \
# 0  Parokya Ni Edgar  0kV35wyXIJKk04VRG0DdF4  168493.0         2003
# 1      Caleb Santos  4TyVEjoScAou6qVjhXyYfp  233728.0   2016-12-02
# 2      Thyro & Yumi  0tSrGWDVpvBzlD8OWSRmg6  259714.0   2020-04-17
# 3      South Border  6bMej3xtNOTiiHLdhR4wzX  347120.0   2005-01-01
# 4   krissy & ericka  5M4GVkxOl3joHIkvNrAlbJ  246280.0   2011-01-01
#
#    popularity  danceability  energy  ...             playlist_id  \
# 0          70         0.636   0.159  ...  37i9dQZF1DX4olOMiqFeqU
# 1          63         0.474   0.522  ...  37i9dQZF1DX4olOMiqFeqU
# 2          11         0.571   0.534  ...  37i9dQZF1DX4olOMiqFeqU
# 3          63         0.660   0.224  ...  37i9dQZF1DX4olOMiqFeqU
# 4          61         0.503   0.357  ...  37i9dQZF1DX4olOMiqFeqU
#
#    playlist_name  genre  duration_ms  num_artists  duration_mins  \
# 0  OPM Favorites    opm          NaN          NaN            NaN
# 1  OPM Favorites    opm          NaN          NaN            NaN
# 2  OPM Favorites    opm          NaN          NaN            NaN
# 3  OPM Favorites    opm          NaN          NaN            NaN
# 4  OPM Favorites    opm          NaN          NaN            NaN
#
#    predicted_genre_id  predicted_genre  \
# 0                   2          sad_opm
# 1                   2          sad_opm
# 2                   1              pop
# 3                   2          sad_opm
# 4                   2          sad_opm
#
#                                  genre_probabilities predicted_genre_proba
# 0  [0.15651337802410126, 0.23137208819389343, 0.6...              0.612115
# 1  [0.12506943941116333, 0.2205456644296646, 0.65...              0.654385
# 2  [0.20713064074516296, 0.5184634327888489, 0.27...              0.518463
# 3  [0.16332723200321198, 0.13600462675094604, 0.7...              0.700668
# 4  [0.12207961082458496, 0.1238289400935173, 0.75...              0.754091
#
# [5 rows x 29 columns]

# %%
tracks_df['genre_probabilities'].values[0]
# Out:
# [0.15651337802410126, 0.23137208819389343, 0.6121145486831665]

# %% [markdown]
# Split genre probabilities to its own columns

# %%
genre_cols = [f'genre_{genre}_proba' for genre in genre_lookup.values()]
tracks_df[genre_cols] = tracks_df['genre_probabilities'].apply(pd.Series)
tracks_df = tracks_df.drop(columns=['genre_probabilities'])#drop column with probability list
tracks_df
# Out:
#                      track_id                            track_name  \
# 0      3OpGUlDmRUXh0NkIYWoIlD                             Your Song
# 1      761frfZtZ8I2g70UsjFfBK                 I Need You More Today
# 2      4r3wYgrJ3Q30ldSk05e6KP                Kiss (Never Let Me Go)
# 3      3VcVQmMivq2ISfKUmIuvMK                               Rainbow
# 4      1FHCU1rDAeaPsBW9byjJ0Q                                 12:51
# ...                       ...                                   ...
# 23040  3OdIiWnYRHPYtC313Z0Bwy                              Face-off
# 23041  5Hfnps0jaWFpYg55WOPexG                                 Alone
# 23043  2qg2jy3v50RwfV5FAqG3a2                      Interlude : Dive
# 23053  2YXswOX5aKv6OHRKUcAMLQ                        All Eyes On Me
# 23054  5qxH7LdIp4QAf1HmSX2Kfu  Cupid Twin Version (Sped Up) - Remix
#
#                     artist_id       artist_name                album_id  \
# 0      2XHTklRsNMOOQT56Zm3WS4  Parokya Ni Edgar  0kV35wyXIJKk04VRG0DdF4
# 1      3XEHRbR9NMWfNzQ6TQMS9M      Caleb Santos  4TyVEjoScAou6qVjhXyYfp
# 2      0001ZVMPt41Vwzt1zsmuzp      Thyro & Yumi  0tSrGWDVpvBzlD8OWSRmg6
# 3      6ZgBJRjJsK1iOJGKGZxEUv      South Border  6bMej3xtNOTiiHLdhR4wzX
# 4      09DdQEMQaaq0f99vqqub3V   krissy & ericka  5M4GVkxOl3joHIkvNrAlbJ
# ...                       ...               ...                     ...
# 23040  1oSPZhvZMIrWW5I41kPkkY             Jimin  4xc3Lc9yASZgEJGH7acWMB
# 23041  1oSPZhvZMIrWW5I41kPkkY             Jimin  4xc3Lc9yASZgEJGH7acWMB
# 23043  1oSPZhvZMIrWW5I41kPkkY             Jimin  4xc3Lc9yASZgEJGH7acWMB
# 23053  6UZ0ba50XreR4TM8u322gs             JISOO  4QuczuzDZNzCDli5Gz6DQ0
# 23054  7xj1YIDzHU6vkUwP76NEyx     Music Factory  4ahvSRXxDEZBO81X2Lq1Ie
#
#        duration release_date  popularity  danceability  energy  ...    genre  \
# 0      168493.0         2003          70         0.636   0.159  ...      opm
# 1      233728.0   2016-12-02          63         0.474   0.522  ...      opm
# 2      259714.0   2020-04-17          11         0.571   0.534  ...      opm
# 3      347120.0   2005-01-01          63         0.660   0.224  ...      opm
# 4      246280.0   2011-01-01          61         0.503   0.357  ...      opm
# ...         ...          ...         ...           ...     ...  ...      ...
# 23040  229627.0   2023-03-24          83         0.689   0.539  ...  unknown
# 23041  211250.0   2023-03-24          82         0.593   0.446  ...  unknown
# 23043  130996.0   2023-03-24          80         0.284   0.495  ...  unknown
# 23053  163522.0   2023-03-31          78         0.779   0.646  ...  unknown
# 23054  146236.0   2023-03-16          74         0.609   0.752  ...  unknown
#
#        duration_ms  num_artists  duration_mins  predicted_genre_id  \
# 0              NaN          NaN            NaN                   2
# 1              NaN          NaN            NaN                   2
# 2              NaN          NaN            NaN                   1
# 3              NaN          NaN            NaN                   2
# 4              NaN          NaN            NaN                   2
# ...            ...          ...            ...                 ...
# 23040          NaN          NaN            NaN                   1
# 23041          NaN          NaN            NaN                   2
# 23043          NaN          NaN            NaN                   0
# 23053          NaN          NaN            NaN                   1
# 23054          NaN          NaN            NaN                   1
#
#         predicted_genre  predicted_genre_proba  genre_alternative_rock_proba  \
# 0               sad_opm               0.612115                      0.156513
# 1               sad_opm               0.654385                      0.125069
# 2                   pop               0.518463                      0.207131
# 3               sad_opm               0.700668                      0.163327
# 4               sad_opm               0.754091                      0.122080
# ...                 ...                    ...                           ...
# 23040               pop               0.655084                      0.169989
# 23041           sad_opm               0.568153                      0.260446
# 23043  alternative_rock               0.351638                      0.351638
# 23053               pop               0.538222                      0.323183
# 23054               pop               0.599818                      0.235381
#
#        genre_pop_proba genre_sad_opm_proba
# 0             0.231372            0.612115
# 1             0.220546            0.654385
# 2             0.518463            0.274406
# 3             0.136005            0.700668
# 4             0.123829            0.754091
# ...                ...                 ...
# 23040         0.655084            0.174926
# 23041         0.171401            0.568153
# 23043         0.320129            0.328233
# 23053         0.538222            0.138596
# 23054         0.599818            0.164800
#
# [17029 rows x 31 columns]

# %% [markdown]
# View histogram of probabilities

# %%
tracks_df['predicted_genre_proba'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Check if model correctly predicts the genre of a track in the Top 200 charts.
#
# - User may validate the results
#
#     - subjectively as a listener
#     - refer to another source by looking up the track in a genre-tagging site(e.g. https://www.chosic.com/music-genre-finder/)

# %% [markdown]
# >Q: Pick a track of choice and check if predicted genre and genre probabilities makes sense

# %%
#######################
# Write code here
tracks_df[tracks_df['track_name']=='Pagkakataon'][['track_name','artist_name','predicted_genre','predicted_genre_proba']]
#
########################
# Out:
#        track_name                      artist_name predicted_genre  \
# 6284  Pagkakataon  ['Shamrock', 'Rachelle Ann Go']             pop
# 6302  Pagkakataon                         Shamrock             pop
#
#       predicted_genre_proba
# 6284               0.683127
# 6302               0.683667

# %% [markdown]
# > Q: Pick a genre and check tracks classified with *highest* predicted genre probability. Does it make sense that the model is confident for this genre prediction?

# %%
#######################
# Write code here
#
tracks_df[tracks_df['predicted_genre']=='sad_opm'][['track_name','artist_name','predicted_genre','predicted_genre_proba']]\
            .sort_values(['predicted_genre_proba'],ascending=False)[:10]

########################
# Out:
#                                            track_name  \
# 7859                    Losing My Religion - Acoustic
# 5039             Don't Know Much (with Aaron Neville)
# 2352                                          Pangako
# 6568                                   I Wont Give Up
# 3581                             Your Love (Acoustic)
# 17302                                           Creep
# 7808   Interstate Love Song - Acoustic; 2019 Remaster
# 18090                                   Where Do I Go
# 709                                        Baka Naman
# 2675                                      Unbreakable
#
#                                         artist_name predicted_genre  \
# 7859                                      Meg Birch         sad_opm
# 5039            ['Linda Ronstadt', 'Aaron Neville']         sad_opm
# 2352   ['RICO J PUNO', 'Marco Sison', 'REY VALERA']         sad_opm
# 6568                                     Jason Chen         sad_opm
# 3581                                         Alamid         sad_opm
# 17302                             The Blue Versions         sad_opm
# 7808                            Stone Temple Pilots         sad_opm
# 18090                                        Side A         sad_opm
# 709                                      Hikohidrio         sad_opm
# 2675       ['Regine Velasquez', 'Moira Dela Torre']         sad_opm
#
#        predicted_genre_proba
# 7859                0.813231
# 5039                0.812084
# 2352                0.811975
# 6568                0.811834
# 3581                0.811455
# 17302               0.810907
# 7808                0.810878
# 18090               0.810577
# 709                 0.810498
# 2675                0.810399

# %% [markdown]
# > Q: Pick another genre and check tracks classified with *lowest* predicted genre probability. Does it make sense that the model is unsure for this genre prediction?

# %%
#######################
# Write code here
tracks_df[tracks_df['predicted_genre']=='alternative_rock'][['track_name','artist_name','predicted_genre','predicted_genre_proba']]\
            .sort_values(['predicted_genre_proba'])[:10]

#
########################
# Out:
#                                 track_name              artist_name  \
# 2250          Ang Pasko'y sumapit na naman          Mabuhay Singers
# 2240                           Noche Buena              The Company
# 17336                      I'm Not In Love   ['Bossa Bros', 'Nara']
# 7855   Tears Don't Fall - Acoustic Version  Bullet For My Valentine
# 6304                           Come and Go            Wred Esguerra
# 10261                          Hey Brother                   Avicii
# 10070                    Walk On the Ocean    Toad The Wet Sprocket
# 222                                    Una              Sponge Cola
# 13419                La Vida Despues De Ti                       LU
# 17183         Somebody That I Used to Know               Mike Dawes
#
#         predicted_genre  predicted_genre_proba
# 2250   alternative_rock               0.344420
# 2240   alternative_rock               0.344706
# 17336  alternative_rock               0.344934
# 7855   alternative_rock               0.344962
# 6304   alternative_rock               0.345162
# 10261  alternative_rock               0.347146
# 10070  alternative_rock               0.348270
# 222    alternative_rock               0.350151
# 13419  alternative_rock               0.350439
# 17183  alternative_rock               0.350941

# %% [markdown]
# ## 5. Save recommender engine pool

# %%
# save data
tracks_df.to_csv("data/spotify_tracks_hale_expanded_ml_rec_pool.csv", index=False, encoding='utf-8')

# %%
# NOTES
# add top 200 charts + pinoy + opm + alt rock + pop + sad opm
